# %% [markdown]
#    4.7                                                      DERIVING NEW VARIABLES

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# Importing the data

# %%
path = r'C:\Users\25670\Desktop\Intercart Basket Analysis16.07.2024'

# %%
path
# Out:
# 'C:\\Users\\25670\\Desktop\\Intercart Basket Analysis16.07.2024'

# %%
# import ords_prods_merge_revised
ords_prods_merge = pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','orders_products_merged.pkl'))

# %%
# import ords_prods_merge_revised
df_ords_prods_merge = pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','orders_products_merged.pkl'))

# %%
#creating a small sub-set
df_ords_prods_merge_sub = df_ords_prods_merge.iloc[0 :1000000,]

# %%
df_ords_prods_merge_sub.shape
# Out:
# (1000000, 17)

# %% [markdown]
# QN.1

# %% [markdown]
# If you haven’t done so already, complete the instructions in the Exercise for creating the “price_label” and “busiest_day” columns.

# %% [markdown]
# Creating "price_label" colomn

# %%
# Define price_label function
def price_label(row):
    if row['prices'] <= 5:
       return 'Low-range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
       return 'Mid-range product'
    elif row['prices'] > 15:
       return 'High range'
    else: return 'Not enough data'

# %%
#Apply the function
df_ords_prods_merge_sub['price_range'] = df_ords_prods_merge_sub.apply(price_label, axis=1)
# Out:
# C:\Users\25670\AppData\Local\Temp\ipykernel_15804\1711050449.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ords_prods_merge_sub['price_range'] = df_ords_prods_merge_sub.apply(price_label, axis=1)

# %%
df_ords_prods_merge_sub['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    652638
# Low-range product    338018
# High range             9344
# Name: count, dtype: int64

# %%
df_ords_prods_merge['prices'].max()
# Out:
# 99999.0

# %% [markdown]
# Creating the "busiest_day" column

# %% [markdown]
# From the past exercises we had 'order_dow' so we have to change see its contents before changing it to 'orders_day_of week'

# %%
ords_prods_merge['order_dow'].value_counts(dropna = False)
# Out:
# order_dow
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
#Change "order_dow" column name to "order_day_of_week"
df_ords_prods_merge.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
df_ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
result = []
for value in df_ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %% [markdown]
# QN.2

# %% [markdown]
# Suppose your clients have changed their minds about the labels you created in your “busiest_day” column.
# Now, they want “Busiest day” to become “Busiest days” (plural).
# This label should correspond with the two busiest days of the week as opposed to the single busiest day.
# At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
# create label for busiest days
df_ords_prods_merge.loc[df_ords_prods_merge['orders_day_of_week'].isin([0, 1]), 'busiest_days'] = 'Busiest Days'

# %%
# create label for regular days
df_ords_prods_merge.loc[df_ords_prods_merge['orders_day_of_week'].isin([6, 2, 5]), 'busiest_days'] = 'Regularly busy Days'

# %%
# create label for slowest days
df_ords_prods_merge.loc[df_ords_prods_merge['orders_day_of_week'].isin([3, 4]), 'busiest_days'] = 'Slowest Days'

# %%
df_ords_prods_merge['busiest_day'] = result

# %%
df_ords_prods_merge['busiest_day'].value_counts(dropna =False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %% [markdown]
# QN.3

# %% [markdown]
# Check the values of this new column for accuracy. Note any observations in markdown format.

# %%
# check value counts for busiest_days
df_ords_prods_merge['busiest_days'].value_counts(dropna = False)
# Out:
# busiest_days
# Regularly busy Days    12916111
# Busiest Days           11864412
# Slowest Days            7624336
# Name: count, dtype: int64

# %%
# check value counts for busiest_day to compare with busiest_days
df_ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %%
# confirm total number of counts are equal for both new columns
df_ords_prods_merge['busiest_day'].shape == df_ords_prods_merge['busiest_days'].shape
# Out:
# True

# %%
# check output
df_ords_prods_merge.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0.1  Unnamed: 0_y  order_id  user_id  \
# 0             19     5.8          1987          1987   3139998      138
# 1             19     5.8          1989          1989   1977647      138
# 2             19     5.8         11433         11433    389851      709
# 3             19     5.8         12198         12198    652770      764
# 4             19     5.8         12200         12200   1813452      764
#
#    order_number  orders_day_of_week  order_hour_of_day  \
# 0            28                   6                 11
# ...

# %% [markdown]
# Question 3 Answers
#
# As expected, the busiest_days value counts are much closer together than the busiest_day value counts because we are now grouping the days in groups
# of 2 or 3 days as opposed 1 or 5 days. We also see that the total counts are equal for both as we would expect.

# %% [markdown]
# QN.4

# %% [markdown]
# When too many users make Instacart orders at the same time, the app freezes.
# The senior technical officer at Instacart wants you to identify the busiest hours of the day.
# Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.”
# Create a new column containing these labels called “busiest_period_of_day.

# %%
# create a list of hours sorted by value count
hours_sorted = df_ords_prods_merge['order_hour_of_day'].value_counts(dropna = False).index.to_numpy()

# %%
# create empty list and for-loop to populate list with busiest time of day labels
busiest_hour = []
   
for row in df_ords_prods_merge["order_hour_of_day"]:
       if row in hours_sorted[:8]:
           busiest_hour.append("Most orders")
       elif row in hours_sorted[8:16]:
          busiest_hour.append("Average orders")
       else:
         busiest_hour.append("Fewest orders")

# %%
busiest_hour
# Out:
# ['Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Fewest orders',
#  'Average orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Fewest orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
# create column in data frame equal to busiest_hour
df_ords_prods_merge['busiest_period_of_day'] = busiest_hour

# %%
# check output
df_ords_prods_merge.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0.1  Unnamed: 0_y  order_id  user_id  \
# 0             19     5.8          1987          1987   3139998      138
# 1             19     5.8          1989          1989   1977647      138
# 2             19     5.8         11433         11433    389851      709
# 3             19     5.8         12198         12198    652770      764
# 4             19     5.8         12200         12200   1813452      764
#
#    order_number  orders_day_of_week  order_hour_of_day  \
# 0            28                   6                 11
# ...

# %% [markdown]
# QN.5

# %% [markdown]
# Print the frequency for this new column.

# %%
df_ords_prods_merge['busiest_period_of_day'] = result

# %%
# check frequency of busiest_period_of_day
df_ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %% [markdown]
# QN.7

# %% [markdown]
# Export your dataframe as a pickle file (since you added new columns) and store it correctly in your “Prepared Data” folder

# %%
# Export to pickle file
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merged_derived.pkl'))
